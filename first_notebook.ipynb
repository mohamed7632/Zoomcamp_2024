# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
df = pd.read_csv('data/green_tripdata_2019-09.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79678 entries, 0 to 79677
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               79678 non-null  int64
#  1   lpep_pickup_datetime   79678 non-null  object
#  2   lpep_dropoff_datetime  79678 non-null  object
#  3   store_and_fwd_flag     79678 non-null  object
#  4   RatecodeID             79678 non-null  int64
#  5   PULocationID           79678 non-null  int64
#  6   DOLocationID           79678 non-null  int64
#  7   passenger_count        79678 non-null  int64
#  8   trip_distance          79677 non-null  float64
#  9   fare_amount            79677 non-null  float64
#  10  extra                  79677 non-null  float64
#  11  mta_tax                79677 non-null  float64
#  12  tip_amount             79677 non-null  float64
#  13  tolls_amount           79677 non-null  float64
# ...

# %%
df.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2019-09-01 00:10:53   2019-09-01 00:23:46                  N
# 1         2  2019-09-01 00:31:22   2019-09-01 00:44:37                  N
# 2         2  2019-09-01 00:50:24   2019-09-01 01:03:20                  N
# 3         2  2019-09-01 00:27:06   2019-09-01 00:33:22                  N
# 4         2  2019-09-01 00:43:23   2019-09-01 00:59:54                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0           1            65           189                5           2.00
# 1           1            97           225                5           3.20
# 2           1            37            61                5           2.99
# 3           1           145           112                1           1.73
# 4           1           112           198                1           3.42
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# ...

# %%
taxi_zone_df = pd.read_csv('data/taxi+_zone_lookup.csv')
#taxi_zone_df = taxi_zone_df.reset_index(drop=True)
taxi_zone_df.head()
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')
engine.connect()

# %%
query = """
SELECT *
FROM pg_catalog.pg_tables
WHERE schemaname != 'pg_catalog' AND 
    schemaname != 'information_schema';
"""

pd.read_sql(query, con=engine)
# Out:
#   schemaname         tablename tableowner tablespace  hasindexes  hasrules  \
# 0     public  green_taxi_trips       root       None       False     False
#
#    hastriggers  rowsecurity
# 0        False        False

# %%
df.to_sql('tgt_green_taxi_trips',engine,if_exists = 'append')
# Out:
# 678

# %%
taxi_zone_df.to_sql('lkp_taxi_zone',engine,if_exists = 'append')
# Out:
# 265
